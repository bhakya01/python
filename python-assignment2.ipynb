# %% [markdown]
# <a href="https://colab.research.google.com/github/bhakya01/python/blob/main/python-assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# STRING CONCATNATED, SCALING,METODS

# %% [markdown]
# '

# %%
STR1 =input("Enter the name")
STR2= input ("get the name")
RESULT=STR1+ "  "+STR2
print("Concatenated String:", RESULT)
# Out:
# Enter the nameRAVI
# get the nameHELLO
# Concatenated String: RAVI  HELLO

# %%
STR2=input("get the name")
STR3=input("Enter the name ")
result1= STR2+"  "+STR3
print("concatenated string :", result1)
# Out:
# get the namehello
# Enter the name world pyhon
# concatenated string : hello  world pyhon

# %% [markdown]
# SCALING AND INDEX

# %%
 S = "welcometopython"
 print(S[0])
# Out:
# w

# %%
 print(S[14])
# Out:
# n

# %%
   print(S[5:14])
# Out:
# metopytho

# %%
 print(S[1:11])
# Out:
# elcometopy

# %%
print(S[::-1])
# Out:
# nohtypotemoclew

# %%
print(S[9:15])
# Out:
# python

# %% [markdown]
# STRING METHOD

# %%
M="python for bigenner"
upper_text=M.upper()Tprint(upper_text)
# Out:
# PYTHON FOR BIGENNER

# %%
M="python for bigenner"
lower_text=M.lower()
print(lower_text)
# Out:
# python for bigenner

# %%
  M="python for bignner"

  print(M.capitalize())
# Out:
# Python for bignner

# %%
M="python for bignner"

print(M.count("n"))
# Out:
# 3

# %%
from os import replace
M="python for bignner"
replace_text=M.replace("python", "Data Analytics")
print(replace_text)
# Out:
# Data Analytics for bignner

# %% [markdown]
#   TUPLE

# %%
A=(10,20,30)
B=(40,50,60)
t_combaine=A+B
print("concatenated:",t_combaine)
# Out:
# concatenated: (10, 20, 30, 40, 50, 60)

# %%
A=(10,20,30)
B=(40,50,60)
repeat= A*3
print(repeat)
# Out:
# (10, 20, 30, 10, 20, 30, 10, 20, 30)

# %%
A=(10,20,30)
B=(40,50,60)
t_combaine=A+B

print(t_combaine[2])
# Out:
# 30

# %%
A=(10,20,30)
B=(40,50,60)
t_combaine=A+B
print(t_combaine[:3])
# Out:
# (10, 20, 30)

# %%
A=(10,20,30)
B=(40,50,60)
t_combaine=A+B
print(t_combaine[-3:])
# Out:
# (40, 50, 60)
